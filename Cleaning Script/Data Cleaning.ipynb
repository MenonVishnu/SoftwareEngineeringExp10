# %% [markdown]
# # Amazon Prime Data

# %%
import pandas as pd

# %%
amazon_data = pd.read_csv('.././DATA/amazon prime movies.csv')
amazon_data = amazon_data.assign(Platform='Amazon')
amazon_data.head(30)
# Out:
#                                       Movie Name   Language IMDb Rating  \
# 0                                     John Rambo      Tamil           7
# 1                                   American Pie    English           7
# 2                                      Bombshell    English         6.8
# 3                                     Love Birds      Tamil         5.1
# 4                                          Hippi     Telugu           5
# 5                    Honey Bunny As Super Team X      Tamil        None
# 6                                          Ayyaa      Tamil         5.7
# 7                                  Mukhya Mantri    Bengali        None
# 8                              Gandhi Fer Aa Gea    Punjabi         4.9
# 9                                 Premada Vayasu    Kannada           6
# 10                        Tum Se Achcha Kaun Hai      Hindi         4.5
# 11                                         Swamy    Kannada           6
# ...

# %%
amazon_data.

# %%
amazon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8127 entries, 0 to 8126
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Movie Name       8127 non-null   object
#  1   Language         8127 non-null   object
#  2   IMDb Rating      8127 non-null   object
#  3   Running Time     8127 non-null   object
#  4   Year of Release  8127 non-null   object
#  5   Maturity Rating  8127 non-null   object
#  6   Plot             8122 non-null   object
# dtypes: object(7)
# memory usage: 444.6+ KB

# %%
amazon_data.count()
# Out:
# Movie Name         8127
# Language           8127
# IMDb Rating        8127
# Running Time       8127
# Year of Release    8127
# Maturity Rating    8127
# Plot               8122
# dtype: int64
