# %% [markdown]
# # Fully Clean Amazon Data

# %%
import pandas as pd

# %%
amazon_data = pd.read_csv('Amazon_Cleaned.csv')
amazon_data.head(40)
# Out:
#        IMDb id                             Name   type  Running Time  Year  \
# 0    tt0163651                     American Pie  Movie          95.0  1999
# 1   tt11452502                        Bombshell  Movie         108.0  2019
# 2    tt0353675                       Love Birds  Movie         160.0  1996
# 3    tt9251858                            Hippi  Movie         140.0  2019
# 4   tt12059768                Gandhi Fer Aa Gea  Movie         133.0  2020
# 5    tt0318956           Tum Se Achcha Kaun Hai  Movie         141.0  2002
# 6   tt12206062                            Swamy  Movie         154.0  2005
# 7    tt7769346     Ekkees Tareekh Shubh Muhurat  Movie          93.0  2018
# 8   tt10168744                  Lonavala Bypass  Movie         106.0  2009
# 9    tt2436386                  Project Almanac  Movie         106.0  2015
# 10   tt6746330                    Ghost Stories  Movie          93.0  2018
# ...

# %%
netflix = pd.read_csv('./../Clean Data/Netflix_Cleaned.csv')
netflix.head()
# Out:
#    Unnamed: 0    imdb_id  title     type  year    age  runtime      genre  \
# 0           1  tt2096351     3%  TV Show  2020  TV-MA     27.0      Drama
# 1           2  tt5979312   7:19    Movie  2016  TV-MA     94.0      Drama
# 2           3  tt2100376  23:59    Movie  2011      R     78.0     Horror
# 3           4  tt0191312      9    Movie  2009  PG-13      NaN  Adventure
# 4           5  tt0224451     21    Movie  2008  PG-13    105.0     Comedy
#
#    rating platform
# 0     7.8  Netflix
# 1     5.9  Netflix
# 2     4.6  Netflix
# 3     5.9  Netflix
# 4     7.2  Netflix

# %%
netflix.drop()
